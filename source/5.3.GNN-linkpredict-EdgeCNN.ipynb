# %%
# !pip install torch_geometric
# Out:
# Collecting torch_geometric
#   Downloading torch_geometric-2.4.0-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 20.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (4.66.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (1.23.5)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (1.11.2)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.1.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (2.31.0)
# Requirement already satisfied: pyparsing in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.0.9)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (1.2.2)
# Requirement already satisfied: psutil>=5.8.0 in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (5.9.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch_geometric) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (2023.7.22)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->torch_geometric) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->torch_geometric) (3.1.0)
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.4.0

# %% [markdown]
# # Đọc dữ liệu

# %%
import pandas as pd
import networkx as nx

# %%
PATH = "/kaggle/input/rnn-with-meetup/data/"

# %%
member_edge = pd.read_csv("/kaggle/input/member-edges-25k/member_edges_25k.csv", index_col=0)

meta_groups = pd.read_csv(PATH + "meta-groups.csv")
meta_members = pd.read_csv(PATH + "meta-members.csv")

# %%
member_edge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24962 entries, 4974 to 11125
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   member1  24962 non-null  int64
#  1   member2  24962 non-null  int64
#  2   weight   24962 non-null  int64
# dtypes: int64(3)
# memory usage: 780.1 KB

# %%
meta_members.head()
# Out:
#    member_id                 name        hometown       city state    lat  \
# 0       2069  Wesley Duffee-Braun       Brentwood  Brentwood    TN  36.00
# 1       8386                  Tim       Nashville  Nashville    TN  36.07
# 2       9205               Brenda       Brentwood  Brentwood    TN  36.00
# 3      17903                Steve             NaN  Nashville    TN  36.13
# 4      20418      Andrea Reynolds  Huntington, WV  Nashville    TN  36.17
#
#      lon
# 0 -86.79
# 1 -86.78
# 2 -86.79
# 3 -86.80
# 4 -86.72

# %%
meta_groups.head()
# Out:
#    group_id                                 group_name  num_members  \
# 0    339011                    Nashville Hiking Meetup        15838
# 1  19728145           Stepping Out Social Dance Meetup         1778
# 2   6335372                           Nashville soccer         2869
# 3  10016242                                     NashJS         1975
# 4  21174496  20's & 30's Women looking for girlfriends         2782
#
#    category_id         category_name  organizer_id             group_urlname
# 0           23  Outdoors & Adventure       4353803          nashville-hiking
# 1            5               Dancing     118484462    steppingoutsocialdance
# 2           32   Sports & Recreation     108448302          Nashville-soccer
# 3           34                  Tech       8111102                    nashjs
# 4           31           Socializing     184580248  new-friends-in-Nashville

# %% [markdown]
# # Xóa bớt liên kết

# %% [markdown]
# ***Vì train nhiều dữ liệu bị tràn ram**

# %%
member_edge_eq1 = member_edge[member_edge['weight'] == 1]
member_edge_eq1 = member_edge_eq1.iloc[:13000,:]
member_edge_eq1['Is_friend'] = 0
member_edge_eq1
# Out:
#               member1    member2  weight  Is_friend
# Unnamed: 0
# 24502        28573892  176110612       1          0
# 18281       195657825  203184347       1          0
# 23394       195231923  161882042       1          0
# 19189       228655199  183381715       1          0
# 17205       204669023  208064791       1          0
# ...               ...        ...     ...        ...
# 20971        96862332   74830542       1          0
# 23030       216367274   42955792       1          0
# 21862        85557392  193874577       1          0
# 24932       230457540  174683552       1          0
# 22660       226951319    8243584       1          0
#
# [12998 rows x 4 columns]

# %%
member_edge_NOT_eq1 = member_edge[member_edge['weight'] != 1]
member_edge_NOT_eq1['Is_friend'] = 1
member_edge_NOT_eq1 = member_edge_NOT_eq1.iloc[:12000,:]
member_edge_NOT_eq1
# Out:
# /tmp/ipykernel_32/1294304853.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member_edge_NOT_eq1['Is_friend'] = 1
#               member1    member2  weight  Is_friend
# Unnamed: 0
# 4974        211551769  158793082       2          1
# 5622         32671432  110832222       2          1
# 2756        214729620  204412550       2          1
# 1252        214761951  211626236       2          1
# 10342       223055408  189716705       2          1
# ...               ...        ...     ...        ...
# 5410          7964302    7980746       2          1
# 1018        226853216  222157019       2          1
# 5646         32671432   11107841       2          1
# 9181        220597234  153185242       2          1
# 11125        49647392  218054797       2          1
#
# [11964 rows x 4 columns]

# %%
member_edge = pd.concat([member_edge_NOT_eq1,member_edge_eq1]).reset_index(drop=True)
member_edge = member_edge.sample(frac = 1, random_state=22)
member_edge
# Out:
#          member1    member2  weight  Is_friend
# 22496  205193250  185666200       1          0
# 10441   14486634   11421826       2          1
# 10307   14225169  190664107       2          1
# 18372  195657825  231812516       1          0
# 12048  195657825   59162062       1          0
# ...          ...        ...     ...        ...
# 23030  217350178  197966717       1          0
# 21862  229310518  225287724       1          0
# 24932  190939281   49647392       1          0
# 22660  191758521   10083446       1          0
# 11125   73895512  218625584       2          1
#
# [24962 rows x 4 columns]

# %%
member_edge.hist()
# Out:
# array([[<Axes: title={'center': 'member1'}>,
#         <Axes: title={'center': 'member2'}>],
#        [<Axes: title={'center': 'weight'}>,
#         <Axes: title={'center': 'Is_friend'}>]], dtype=object)

# %%
member_edge = member_edge.drop(columns=['weight'])
member_edge
# Out:
#          member1    member2  Is_friend
# 22496  205193250  185666200          0
# 10441   14486634   11421826          1
# 10307   14225169  190664107          1
# 18372  195657825  231812516          0
# 12048  195657825   59162062          0
# ...          ...        ...        ...
# 23030  217350178  197966717          0
# 21862  229310518  225287724          0
# 24932  190939281   49647392          0
# 22660  191758521   10083446          0
# 11125   73895512  218625584          1
#
# [24962 rows x 3 columns]

# %% [markdown]
# # Convert Member to Homogeneous Graph

# %% [markdown]
# Let's first identify the graph-specific things we need:
#
# - `Nodes` - Members (by ID)
# - `Edges` - Weight-Shared group membership
# - `Node Features` - hometown, city, state, lat, lon (3 atts maybe affact to Weight)
# - `Labels` - Weight-Shared group membership (node-level regression task)

# %%
from sklearn import preprocessing
import numpy as np

# %%
# Make sure that we have no duplicate nodes
max(meta_members["member_id"].value_counts())
# Out:
# 1

# %% [markdown]
# ## Delete member note edge

# %%
meta_members[meta_members.member_id==198016947]
# Out:
#        member_id           name hometown      city state    lat    lon
# 13190  198016947  Talyna Kellum      NaN  Fairview    TN  35.97 -87.13

# %%
member_inp_edge = member_edge[member_edge['member1'].isin(meta_members.member_id)]
member_inp_edge = member_inp_edge[member_inp_edge['member2'].isin(meta_members.member_id)]
member_label_edge = member_edge[member_edge['member2'].isin(meta_members.member_id)]

# %%
# member_inp_edge = member_inp_edge[(member_inp_edge['weight'] == 1)]
# member_label_edge = member_label_edge[(member_label_edge['weight'] == 1)]

len (member_inp_edge) , len (member_label_edge)
# Out:
# (24961, 24961)

# %%
member_inp_meta_1 = meta_members.rename(columns = {'member_id':'member1'})
member_inp_meta_2 = meta_members.rename(columns = {'member_id':'member2'})
member_inp_meta_1
# Out:
#          member1                 name        hometown       city state    lat  \
# 0           2069  Wesley Duffee-Braun       Brentwood  Brentwood    TN  36.00
# 1           8386                  Tim       Nashville  Nashville    TN  36.07
# 2           9205               Brenda       Brentwood  Brentwood    TN  36.00
# 3          17903                Steve             NaN  Nashville    TN  36.13
# 4          20418      Andrea Reynolds  Huntington, WV  Nashville    TN  36.17
# ...          ...                  ...             ...        ...   ...    ...
# 24586  239513469          Madison Ray             NaN  Nashville    TN  36.09
# 24587  239515413         Jay Hatchett             NaN  La Vergne    TN  36.00
# 24588  239519977     Lukasz Bielawski             NaN  Nashville    TN  36.17
# 24589  239520184         Terri Taylor             NaN  Nashville    TN  36.14
# 24590  239558741             Michelle             NaN  Brentwood    TN  36.00
#
#          lon
# 0     -86.79
# 1     -86.78
# 2     -86.79
# 3     -86.80
# 4     -86.72
# ...      ...
# 24586 -86.82
# 24587 -86.57
# 24588 -86.78
# 24589 -86.74
# 24590 -86.79
#
# [24591 rows x 7 columns]

# %%
member_inp_meta_1 = pd.merge(member_edge, member_inp_meta_1, how="inner", on=["member1"])
member_inp_meta_1
# Out:
#          member1    member2  Is_friend            name       hometown  \
# 0      205193250  185666200          0  Otilia Bilauca            NaN
# 1      205193250  209704842          0  Otilia Bilauca            NaN
# 2      205193250  186045687          0  Otilia Bilauca            NaN
# 3      205193250  197541214          0  Otilia Bilauca            NaN
# 4      205193250  202429218          0  Otilia Bilauca            NaN
# ...          ...        ...        ...             ...            ...
# 24957  194381707   11872972          1           Shawn      Nashville
# 24958   13371408   12134295          1              RJ    Antioch, TN
# 24959   38505422   12128207          1            Jess  Jamestown, TN
# 24960    6458794    3380276          1          Lannae      Nashville
# 24961    9635822  192863475          1         Chessie    clarksville
#
#             city state    lat    lon
# 0      Brentwood    TN  36.00 -86.79
# 1      Brentwood    TN  36.00 -86.79
# 2      Brentwood    TN  36.00 -86.79
# 3      Brentwood    TN  36.00 -86.79
# 4      Brentwood    TN  36.00 -86.79
# ...          ...   ...    ...    ...
# 24957  Nashville    TN  36.17 -86.78
# 24958    Antioch    TN  36.04 -86.64
# 24959  Nashville    TN  36.17 -86.78
# 24960  Nashville    TN  36.16 -86.79
# 24961  Nashville    TN  36.17 -86.78
#
# [24962 rows x 9 columns]

# %%
member_inp_meta_1 = member_inp_meta_1.dropna(subset=['member2'])
member_inp_meta_1["member2"] = member_inp_meta_1["member2"].astype(int)

# %%
meta_edge_members = pd.merge(member_edge, member_inp_meta_2, how="inner", on=["member2"])
meta_edge_members
# Out:
#          member1    member2  Is_friend              name  \
# 0      205193250  185666200          0        Mike Brown
# 1      195657825  185666200          0        Mike Brown
# 2      204669023  185666200          0        Mike Brown
# 3       28573892  185666200          0        Mike Brown
# 4       14486634   11421826          1       kevin.reiss
# ...          ...        ...        ...               ...
# 24956  195657825  197747639          0     Mike Schmitz
# 24957    7864416  226853216          0  Jackson Guerrier
# 24958  214466652  217977208          0     Emma Reynolds
# 24959  217350178  107048712          0          Jonathan
# 24960  214466652  205144653          0       Tyne Foster
#
#                    hometown       city state    lat    lon
# 0                       NaN  Nashville    TN  36.17 -86.72
# 1                       NaN  Nashville    TN  36.17 -86.72
# 2                       NaN  Nashville    TN  36.17 -86.72
# 3                       NaN  Nashville    TN  36.17 -86.72
# 4                  Franklin   Franklin    TN  35.93 -86.81
# ...                     ...        ...   ...    ...    ...
# 24956                   NaN    Lebanon    TN  36.21 -86.31
# 24957                   NaN  Nashville    TN  36.17 -86.78
# 24958                   NaN  Nashville    TN  36.17 -86.78
# 24959             Miami, FL  Nashville    TN  36.15 -86.86
# 24960  Lake Havasu City, AZ  Hermitage    TN  36.19 -86.60
#
# [24961 rows x 9 columns]

# %%
meta_edge_members = meta_edge_members.dropna(subset=['member1'])
meta_edge_members["member1"] = meta_edge_members["member1"].astype(int)

# %%
# meta_members = pd.concat([result_1,result_2]).reset_index(drop=True)
# member_inp_meta_1 = member_inp_meta_1.rename(columns = {'member1':'member_id'})

# %% [markdown]
# ## Node_features

# %%
# Sort to define the order of nodes
sorted_df = member_inp_meta_1.sort_values(by="member1")
# Select node features
## hometown miss a lot value
node_features = sorted_df[["city", "state" , "lat", "lon"]]
# Fill nan
node_features["state"] = node_features["state"].fillna("Nashville")
# Out:
# /tmp/ipykernel_32/4117103657.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   node_features["state"] = node_features["state"].fillna("Nashville")

# %%
# Convert non-numeric columns
pd.set_option('mode.chained_assignment', None)
enc_city = preprocessing.OrdinalEncoder()
enc_state = preprocessing.OrdinalEncoder()

node_features["city_encode"] = node_features["city"]
node_features["state_encode"] = node_features["state"]

node_features[["city_encode"]] = enc_city.fit_transform(node_features[["city_encode"]])
node_features[["state_encode"]] = enc_city.fit_transform(node_features[["state_encode"]])

# %%
node_features.drop(["city", "state"], axis=1, inplace=True)

# %%
node_features.head()
# Out:
#         lat    lon  city_encode  state_encode
# 21938  36.0 -86.79          6.0          13.0
# 21956  36.0 -86.79          6.0          13.0
# 21953  36.0 -86.79          6.0          13.0
# 21952  36.0 -86.79          6.0          13.0
# 21951  36.0 -86.79          6.0          13.0

# %%
# Convert to numpy
x = node_features.to_numpy()
x.shape # [num_nodes x num_features]
# Out:
# (24962, 4)

# %% [markdown]
# ## Labels

# %%
sorted_df = member_inp_meta_1.sort_values(by="member1")
labels = sorted_df["Is_friend"]
labels.tail()
# Out:
# 22790    1
# 22789    1
# 22788    1
# 22784    1
# 22792    1
# Name: Is_friend, dtype: int64

# %%
# Convert to numpy
y = labels.to_numpy()
y.shape
# Out:
# (24962,)

# %% [markdown]
# ## Mask node

# %%
import torch

# Create valid masks for nodes
is_friend = np.array(sorted_df["Is_friend"], dtype=np.float32)
valid_mask = np.argwhere(~np.isnan(is_friend)).reshape(-1)
torch_valid_mask = torch.tensor(valid_mask, dtype=torch.long)
torch_valid_mask
# Out:
# tensor([    0,     1,     2,  ..., 24959, 24960, 24961])

# %% [markdown]
# ## Edges

# %%
member_inp_meta_1.head()
# Out:
#      member1    member2  Is_friend            name hometown       city state  \
# 0  205193250  185666200          0  Otilia Bilauca      NaN  Brentwood    TN
# 1  205193250  209704842          0  Otilia Bilauca      NaN  Brentwood    TN
# 2  205193250  186045687          0  Otilia Bilauca      NaN  Brentwood    TN
# 3  205193250  197541214          0  Otilia Bilauca      NaN  Brentwood    TN
# 4  205193250  202429218          0  Otilia Bilauca      NaN  Brentwood    TN
#
#     lat    lon
# 0  36.0 -86.79
# 1  36.0 -86.79
# 2  36.0 -86.79
# 3  36.0 -86.79
# 4  36.0 -86.79

# %%
sorted_df = member_inp_meta_1.sort_values(by="member1").set_index("member1")
# sorted_df_1 = member_edge.sort_values(by="member1").set_index("member1")
# sorted_df_2 = member_edge.sort_values(by="member2").set_index("member2")

# %%
sorted_df = sorted_df.reset_index(drop=False)
# sorted_df_1 = sorted_df_1.reset_index(drop=False)
# sorted_df_2 = sorted_df_2.reset_index(drop=False)
member_id_mapping = sorted_df["member1"]
# member_id_mapping_1 = sorted_df_1["member1"]
# member_id_mapping_2 = sorted_df_2["member2"]

# %%
member_id_mapping
# Out:
# 0             2069
# 1             2069
# 2             2069
# 3             2069
# 4             2069
#            ...
# 24957    236163083
# 24958    236163083
# 24959    236163083
# 24960    236163083
# 24961    236163083
# Name: member1, Length: 24962, dtype: int64

# %%
print("Before remapping...")
member_inp_meta_1.head()
# Out:
# Before remapping...
#      member1    member2  Is_friend            name hometown       city state  \
# 0  205193250  185666200          0  Otilia Bilauca      NaN  Brentwood    TN
# 1  205193250  209704842          0  Otilia Bilauca      NaN  Brentwood    TN
# 2  205193250  186045687          0  Otilia Bilauca      NaN  Brentwood    TN
# 3  205193250  197541214          0  Otilia Bilauca      NaN  Brentwood    TN
# 4  205193250  202429218          0  Otilia Bilauca      NaN  Brentwood    TN
#
#     lat    lon
# 0  36.0 -86.79
# 1  36.0 -86.79
# 2  36.0 -86.79
# 3  36.0 -86.79
# 4  36.0 -86.79

# %%
# Map member IDs
member_map = member_id_mapping.reset_index().set_index("member1").to_dict()
# member_map_1 = member_id_mapping_1.reset_index().set_index("member1").to_dict()
member_inp_meta_1["member1"] = member_inp_meta_1["member1"].map(member_map["index"]).astype(int)

# member_map_2 = member_id_mapping_2.reset_index().set_index("member2").to_dict()
member_inp_meta_1["member2"] = member_inp_meta_1["member2"].map(member_map["index"])

print("After remapping...")
member_inp_meta_1.head()
# Out:
# After remapping...
#    member1  member2  Is_friend            name hometown       city state  \
# 0    18076      NaN          0  Otilia Bilauca      NaN  Brentwood    TN
# 1    18076      NaN          0  Otilia Bilauca      NaN  Brentwood    TN
# 2    18076      NaN          0  Otilia Bilauca      NaN  Brentwood    TN
# 3    18076      NaN          0  Otilia Bilauca      NaN  Brentwood    TN
# 4    18076      NaN          0  Otilia Bilauca      NaN  Brentwood    TN
#
#     lat    lon
# 0  36.0 -86.79
# 1  36.0 -86.79
# 2  36.0 -86.79
# 3  36.0 -86.79
# 4  36.0 -86.79

# %%
member_inp_meta_1 = member_inp_meta_1.dropna(subset=['member2'])
member_inp_meta_1["member2"] = member_inp_meta_1["member2"].astype(int)

# %%
edge_index = member_inp_meta_1[["member1", "member2"]].values.transpose()
edge_index.shape # [2 x num_edges]
# Out:
# (2, 1563)

# %% [markdown]
# ### Label edge index

# %%
meta_edge_members
# Out:
#          member1    member2  Is_friend              name  \
# 0      205193250  185666200          0        Mike Brown
# 1      195657825  185666200          0        Mike Brown
# 2      204669023  185666200          0        Mike Brown
# 3       28573892  185666200          0        Mike Brown
# 4       14486634   11421826          1       kevin.reiss
# ...          ...        ...        ...               ...
# 24956  195657825  197747639          0     Mike Schmitz
# 24957    7864416  226853216          0  Jackson Guerrier
# 24958  214466652  217977208          0     Emma Reynolds
# 24959  217350178  107048712          0          Jonathan
# 24960  214466652  205144653          0       Tyne Foster
#
#                    hometown       city state    lat    lon
# 0                       NaN  Nashville    TN  36.17 -86.72
# 1                       NaN  Nashville    TN  36.17 -86.72
# 2                       NaN  Nashville    TN  36.17 -86.72
# 3                       NaN  Nashville    TN  36.17 -86.72
# 4                  Franklin   Franklin    TN  35.93 -86.81
# ...                     ...        ...   ...    ...    ...
# 24956                   NaN    Lebanon    TN  36.21 -86.31
# 24957                   NaN  Nashville    TN  36.17 -86.78
# 24958                   NaN  Nashville    TN  36.17 -86.78
# 24959             Miami, FL  Nashville    TN  36.15 -86.86
# 24960  Lake Havasu City, AZ  Hermitage    TN  36.19 -86.60
#
# [24961 rows x 9 columns]

# %%
print("Before remapping...")
meta_edge_members.head()
# Out:
# Before remapping...
#      member1    member2  Is_friend         name  hometown       city state  \
# 0  205193250  185666200          0   Mike Brown       NaN  Nashville    TN
# 1  195657825  185666200          0   Mike Brown       NaN  Nashville    TN
# 2  204669023  185666200          0   Mike Brown       NaN  Nashville    TN
# 3   28573892  185666200          0   Mike Brown       NaN  Nashville    TN
# 4   14486634   11421826          1  kevin.reiss  Franklin   Franklin    TN
#
#      lat    lon
# 0  36.17 -86.72
# 1  36.17 -86.72
# 2  36.17 -86.72
# 3  36.17 -86.72
# 4  35.93 -86.81

# %%
sorted_df = member_inp_meta_2.sort_values(by="member2").set_index("member2")
sorted_df = sorted_df.reset_index(drop=False)
# sorted_df_1 = sorted_df_1.reset_index(drop=False)
# sorted_df_2 = sorted_df_2.reset_index(drop=False)
member_id_mapping = sorted_df["member2"]

# %%
# Map member IDs
member_map = member_id_mapping.reset_index().set_index("member2").to_dict()
# member_map_1 = member_id_mapping_1.reset_index().set_index("member1").to_dict()
meta_edge_members["member1"] = meta_edge_members["member1"].map(member_map["index"])

# member_map_2 = member_id_mapping_2.reset_index().set_index("member2").to_dict()
meta_edge_members["member2"] = meta_edge_members["member2"].map(member_map["index"]).astype(int)

print("After remapping...")
meta_edge_members.head()
# Out:
# After remapping...
#    member1  member2  Is_friend         name  hometown       city state    lat  \
# 0    15321    10027          0   Mike Brown       NaN  Nashville    TN  36.17
# 1    12499    10027          0   Mike Brown       NaN  Nashville    TN  36.17
# 2    15191    10027          0   Mike Brown       NaN  Nashville    TN  36.17
# 3     3504    10027          0   Mike Brown       NaN  Nashville    TN  36.17
# 4     3005     2000          1  kevin.reiss  Franklin   Franklin    TN  35.93
#
#      lon
# 0 -86.72
# 1 -86.72
# 2 -86.72
# 3 -86.72
# 4 -86.81

# %%
meta_edge_members = meta_edge_members.dropna(subset=['member1'])
meta_edge_members["member1"] = meta_edge_members["member1"].astype(int)

# %%
edge_label_index = meta_edge_members[["member1", "member2"]].values.transpose()
edge_label_index.shape # [2 x num_edges]
# Out:
# (2, 24961)

# %%
sorted_df_2 = meta_edge_members.sort_values(by="member2")

# %%
edge_label = sorted_df_2["Is_friend"]
edge_label.tail()
# Out:
# 19478    0
# 21034    0
# 664      0
# 9653     0
# 23364    0
# Name: Is_friend, dtype: int64

# %%
# Convert to numpy
edge_label = edge_label.to_numpy()
edge_label.shape
# Out:
# (24961,)

# %% [markdown]
# #### Label edge index train/test: 70/30

# %%
edge_label_train = edge_label[:int(0.7*edge_label_index.shape[1])]
edge_label_test = edge_label[int(0.7*edge_label_index.shape[1]):]

# %%
edge_label_index_train = edge_label_index[:,:int(0.7*edge_label_index.shape[1])]
edge_label_index_test = edge_label_index[:,int(0.7*edge_label_index.shape[1]):]

# %% [markdown]
# ## Convert to pytorch dataset

# %%
from torch_geometric.data import Data
# # full data
# data = Data(x=torch.tensor(x, dtype=torch.float), y=torch.tensor(y, dtype=torch.float),
#                             edge_index=torch.tensor(edge_index, dtype=torch.long),
#                             valid_mask=torch_valid_mask,
#                             edge_label=torch.tensor(edge_label, dtype=torch.float),
#                             edge_label_index=torch.tensor(edge_label_index, dtype=torch.long))

# data

# %%
data_train = Data(x=torch.tensor(x, dtype=torch.float), y=torch.tensor(y, dtype=torch.float),
                            edge_index=torch.tensor(edge_index, dtype=torch.long),
                            valid_mask=torch_valid_mask,
                            edge_label=torch.tensor(edge_label_train, dtype=torch.float),
                            edge_label_index=torch.tensor(edge_label_index_train, dtype=torch.long))

# %%
data_train
# Out:
# Data(x=[24962, 4], edge_index=[2, 1563], y=[24962], valid_mask=[24962], edge_label=[17472], edge_label_index=[2, 17472])

# %%
data_test = Data(x=torch.tensor(x, dtype=torch.float), y=torch.tensor(y, dtype=torch.float),
                            edge_index=torch.tensor(edge_index, dtype=torch.long),
                            valid_mask=torch_valid_mask,
                            edge_label=torch.tensor(edge_label_test, dtype=torch.float),
                            edge_label_index=torch.tensor(edge_label_index_test, dtype=torch.long))

# %%
data_test
# Out:
# Data(x=[24962, 4], edge_index=[2, 1563], y=[24962], valid_mask=[24962], edge_label=[7489], edge_label_index=[2, 7489])

# %% [markdown]
# # Build model Member

# %% [markdown]
# ## Link member prediction

# %%
from torch_geometric.nn.models import EdgeCNN

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
from torch_geometric.nn import GCNConv
from torch_geometric.utils import negative_sampling
from sklearn.metrics import roc_auc_score
import numpy as np

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %%
class Net(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels):
        super().__init__()
        self.model_EdgeCNN = EdgeCNN(in_channels=in_channels, hidden_channels=hidden_channels,
                                num_layers=6, out_channels=out_channels)

    def encode(self, x, edge_index):
        out = self.model_EdgeCNN(x, edge_index)
        return out

    def decode(self, z, edge_label_index):
        return (z[edge_label_index[0]] * z[edge_label_index[1]]).sum(dim=-1)

    def decode_all(self, z):
        prob_adj = z @ z.t()
        #return the indices of a non-zero element
        return (prob_adj > 1).nonzero(as_tuple=False).t()

# %%
model = Net(data_train.num_features, 128, 64).to(device)
optimizer = torch.optim.Adam(params=model.parameters(), lr=0.00001)
criterion = torch.nn.BCEWithLogitsLoss()

# %%
def train():
    model.train()
    optimizer.zero_grad()
    z = model.encode(data_train.x, data_train.edge_index)

#     # We perform a new round of negative sampling for every training epoch:
#     neg_edge_index = negative_sampling(
#         edge_index=data_train.edge_index, num_nodes=data_train.num_nodes,
#         num_neg_samples=data_train.edge_label_index.size(1))

    edge_label_index = torch.cat(
        [data_train.edge_label_index],#neg_edge_index
        dim=-1,
    )
    edge_label = torch.cat([
        data_train.edge_label
    ], dim=0) #data_train.edge_label.new_zeros(neg_edge_index.size(1))

    out = model.decode(z, edge_label_index).view(-1)
    loss = criterion(out, edge_label)
    loss.backward()
    optimizer.step()
    return loss

@torch.no_grad()
def test(data):
    model.eval()
    z = model.encode(data.x, data.edge_index)
    out = model.decode(z, data.edge_label_index).view(-1).sigmoid()
    return roc_auc_score(data.edge_label.cpu().numpy(), out.cpu().numpy())

# %%
best_val_auc = final_test_auc = 0
for epoch in range(1, 15):
    loss = train()
    val_auc = test(data_test)
#     test_auc = test(data_test)
    if val_auc > best_val_auc:
        best_val_auc = val_auc
#         final_test_auc = test_auc
    print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}, Val: {val_auc:.4f},')

print(f'Final Test: {best_val_auc:.4f}')
# Out:
# Epoch: 001, Loss: 0.6932, Val: 0.5000,
# Epoch: 002, Loss: 0.6932, Val: 0.5000,
# Epoch: 003, Loss: 0.6932, Val: 0.5000,
# Epoch: 004, Loss: 0.6932, Val: 0.5000,
# Epoch: 005, Loss: 0.6932, Val: 0.5000,
# Epoch: 006, Loss: 0.6932, Val: 0.5000,
# Epoch: 007, Loss: 0.6932, Val: 0.5000,
# Epoch: 008, Loss: 0.6932, Val: 0.5000,
# Epoch: 009, Loss: 0.6932, Val: 0.5000,
# Epoch: 010, Loss: 0.6932, Val: 0.5000,
# Epoch: 011, Loss: 0.6932, Val: 0.5000,
# Epoch: 012, Loss: 0.6932, Val: 0.5000,
# Epoch: 013, Loss: 0.6932, Val: 0.5000,
# Epoch: 014, Loss: 0.6932, Val: 0.5000,
# Final Test: 0.5000

# %% [markdown]
# ## Kết luận: 3 Yếu tố không ảnh hưởng đến liên kết

# %% [markdown]
# # Predict plot

# %% [markdown]
# ## Kết luận: Mô hình này ko train được với các thuộc tính hiện có

# %%
z = model.encode(data_test.x, data_test.edge_index)
final_edge_index = model.decode(z,data_test.edge_label_index)

# %%
final_edge_index
# Out:
# tensor([0., 0., 0.,  ..., 0., 0., 0.], grad_fn=<SumBackward1>)

# %%
df_pred = pd.DataFrame(edge_label_index_test.T)
df_pred['Is_friend'] = edge_label_test
df_pred['predict'] = final_edge_index.detach().numpy()

# %%
# df_pred['Is_friend_pred'] = 1 
# df_pred

# %%
df_pred.predict.value_counts()
# Out:
# predict
# 0.0    7489
# Name: count, dtype: int64

# %%
df_pred = df_pred[df_pred['predict'] > np.mean(df_pred['predict'])]

# %%
df_pred
# Out:
# Empty DataFrame
# Columns: [0, 1, Is_friend, predict]
# Index: []

# %%
G = nx.from_pandas_edgelist(df_pred, 0, 1, create_using = nx.Graph())

# %%
nx.draw(G,pos=nx.spring_layout(G),node_color='black',alpha=0.3,node_size=10,edge_color='orange',width=1)
